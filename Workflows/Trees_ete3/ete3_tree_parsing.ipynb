# %% [markdown]
# # Parse trees adding the information from the `bactaxR`'s clusters and any other table(s) to the leaves' names
#
# The aim is to add useful information to the tip labels/leaves' names of a tree. Here, we add the cluster assignments accoding to `bactaxR` and the taxonomic classification according to `GTDB-tk`

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import re
from collections import defaultdict
from ete3 import Tree

# %% [markdown]
# ## Read a table with relevant information
#
# This table contains the species classification according to `GTDB-tk`

# %%
table = '/run/media/mibu/LR-orico_mini/Recovery_ADATA/Umayor/Work/Akker/Verrucomicrobia/QC/merged_akk_hand_edited.tsv'
merged_df = pd.read_csv(table, sep='\t')
# Create a new column representing the gtdb species classification
merged_df['GTDB_specie'] = merged_df['classification'].str.extract(';(s_.+)')
merged_df.info()
merged_df.head(2)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 201 entries, 0 to 200
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Genome                       201 non-null    object
#  1   Completeness                 201 non-null    float64
#  2   Contamination                201 non-null    float64
#  3   classification               201 non-null    object
#  4   classification_method        201 non-null    object
#  5   sum_len                      201 non-null    int64
#  6   N50                          201 non-null    int64
#  7   16S ribosomal RNA > 1400 nt  151 non-null    float64
#  8   Total_tRNAs                  201 non-null    int64
#  9   host                         198 non-null    object
#  10  NCBI_organism_name           147 non-null    object
#  11  NCBI_infraspecific_name      140 non-null    object
#  12  relation_to_type_material    4 non-null      object
#  13  type_of_sample               201 non-null    object
#  14  GTDB_specie                  201 non-null    object
# dtypes: float64(3), int64(3), object(9)
# memory usage: 23.7+ KB
#                                               Genome  Completeness  \
# 0            DGYMR06203__metabat2_low_PE.047.contigs         91.12
# 1  F157a_European_Toad__metabat2_high_PE.005.contigs         89.32
#
#    Contamination                                     classification  \
# 0            0.0  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
# 1            2.3  d__Bacteria;p__Verrucomicrobiota;c__Verrucomic...
#
#                                classification_method  sum_len    N50  \
# 0  taxonomic classification defined by topology a...  2417897  26278
# 1  taxonomic classification defined by topology a...  2029501   8457
#
#    16S ribosomal RNA > 1400 nt  Total_tRNAs           host NCBI_organism_name  \
# 0                          NaN           44  gallus gallus                NaN
# 1                          NaN           40      bufo bufo                NaN
#
#   NCBI_infraspecific_name relation_to_type_material type_of_sample  \
# 0                     NaN                       NaN     metagenome
# 1                     NaN                       NaN     metagenome
#
#                   GTDB_specie
# 0  s__Akkermansia sp900548895
# 1                         s__

# %% [markdown]
# ## Create the dictionary to add the species name

# %%
asm_to_sp = defaultdict()
for i, row in merged_df[['Genome','GTDB_specie']].iterrows():
    asm_to_sp[row['Genome']] = row['GTDB_specie']#.str.replace('s__', '')
len(asm_to_sp)
# Out:
# 201

# %% [markdown]
# ## Parse the trees
# We have more than one `bactaxR` table, each one created with a particular ANI treshold. For each of those tables, we create a parsed tree.

# %%
# root path where tables are located
bac_path = Path("FastANI/bactaxR_related/")
# our tables. It's important that the names of the tables contain the ani
# threshold used to create them, because we use it in the output name (parsed tree)
cluster_f = ['g_akk_clusters_96.5.tsv', 'g_akk_clusters_97.tsv']

for f in cluster_f:
    Read the table with cluster assignments from `bactaxR`
    clusters = pd.read_csv(bac_path.joinpath(f), sep='\t')
    # mapping from species (assembly name) to cluster assignment 
    sp_to_clust = defaultdict()
    for i, row in clusters[['Cluster', 'Genome']].iterrows():
        sp_to_clust[row['Genome']] = row['Cluster']
    print(len(sp_to_clust))
    
    #Read the orthofinder tree
    root = Path("/Species_Tree")
    tree_f = root.joinpath('SpeciesTree_rooted_node_labels.txt')
    tree = Tree(tree_f.as_posix(), format=1)
    
    for node in tree.traverse():
    # check if the node.name is in the table, sometimes the table/asm_to_sp
    # doesn't have all the information
        if node.is_leaf() and node.name in asm_to_sp.keys():
            # build the new leaf name from the previous 2 dictionaries
            node.name = f'{asm_to_sp[node.name]} | {sp_to_clust[node.name]} | {node.name}'
    # get the ani threshold to use it in the output name. Change it if you have other pattern 
    # in the input files' names.
    suf = re.search(r'_([0-9]{2}\.?[0-9]?).tsv', f).group(1) 
    # The output tree, one for each bactaxr table
    tree_outf = root.joinpath(f'species_tree_{suf}.nwk')
    tree.write(format=1, outfile=tree_outf.as_posix())

# print the last tree 
print(tree)
# Out:
# 201
# 201
#
#    /-GCF_000172155.1_ASM17215v1_genomic
#   |
#   |               /-s__Akkermansia sp900545155 | 1 | GCA_905197035.1_ERR2013654-mag-bin.36_genomic
#   |            /-|
#   |           |   \-s__Akkermansia sp900545155 | 1 | GCA_900545155.1_UMGS750_genomic
#   |         /-|
#   |        |  |   /-s__Akkermansia sp900545155 | 2 | GCA_900765745.1_SRS294966_17_genomic
#   |      /-|   \-|
#   |     |  |      \-s__Akkermansia sp900545155 | 3 | MGYG-HGUT-02584
#   |     |  |
#   |     |   \-s__ | 1 | F157a_European_Toad__metabat2_high_PE.005.contigs
#   |     |
#   |     |         /-s__Akkermansia sp004167605 | 4 | GCA_900759685.1_ERS608607_23_genomic
#   |     |        |
#   |     |      /-|      /-s__Akkermansia sp004167605 | 4 | GCA_905210405.1_ERR321569-mag-bin.26_genomic
#   |     |     |  |   /-|
#   |     |     |  |  |   \-s__Akkermansia sp004167605 | 4 | GCF_008422275.1_ASM842227v1_genomic
#   |     |     |   \-|
#   |     |     |     |   /-s__Akkermansia sp004167605 | 4 | GCA_900539575.1_UMGS141_genomic
#   |     |     |      \-|
#   |     |   /-|         \-s__Akkermansia sp004167605 | 4 | MGYG-HGUT-00870
#   |     |  |  |
#   |     |  |  |      /-s__Akkermansia sp001580195 | 5 | MGG28571
#   |     |  |  |   /-|
#   |     |  |  |  |  |   /-s__Akkermansia sp001580195 | 5 | GCA_905205915.1_ERR1305901-mag-bin.46_genomic
#   |     |  |  |  |   \-|
#   |     |  |  |  |      \-s__Akkermansia sp001580195 | 5 | GCA_900539895.1_UMGS181_genomic
#   |     |  |   \-|
#   |     |  |     |      /-s__Akkermansia sp001580195 | 8 | MGYG-HGUT-02378
#   |   /-|  |     |   /-|
#   |  |  |  |     |  |   \-s__Akkermansia sp001580195 | 8 | GCF_001578645.1_ASM157864v1_genomic
#   |  |  |  |      \-|
#   |  |  |  |        |   /-s__Akkermansia sp001580195 | 8 | GCF_001647615.1_ASM164761v1_genomic
#   |  |  |  |         \-|
#   |  |  |  |            \-s__Akkermansia sp001580195 | 8 | GCF_001580195.1_ASM158019v1_genomic
#   |  |  |  |
#   |  |  |  |               /-s__Akkermansia muciniphila_C | 6 | MGG23710
#   |  |  |  |            /-|
  |  |   /-s__Akkermansia muciniphila | 1 | GCF_004104435.1_ASM410443v1_genomic
#   |  |                  \-|  |   \-|
#   |  |                    |  |     |   /-s__Akkermansia muciniphila | 1 | GCF_002885655.1_ASM288565v1_genomic
#    \-|                    |  |      \-|
#      |                    |  |         \-s__Akkermansia muciniphila | 1 | GCF_002885255.1_ASM288525v1_genomic
#      |                    |  |
#      |                    |  |         /-s__Akkermansia muciniphila | 1 | GCF_002885155.1_ASM288515v1_genomic
#      |                    |  |        |
#      |                    |  |      /-|   /-s__Akkermansia muciniphila | 1 | GCA_000436395.1_MGS154_genomic
#      |                    |  |     |  |  |
#      |                    |  |     |   \-|   /-s__Akkermansia muciniphila | 1 | GCF_002885195.1_ASM288519v1_genomic
#      |                     \-|     |     |  |
#      |                       |     |      \-|      /-s__Akkermansia muciniphila | 1 | GCF_004015225.1_ASM401522v1_genomic
#      |                       |     |        |   /-|
#      |                       |   /-|        |  |   \-s__Akkermansia muciniphila | 1 | GCF_004015085.1_ASM401508v1_genomic
#      |                       |  |  |         \-|
#      |                       |  |  |           |   /-s__Akkermansia muciniphila | 1 | GCF_004015205.1_ASM401520v1_genomic
#      |                       |  |  |            \-|
#      |                       |  |  |               \-s__Akkermansia muciniphila | 1 | GCF_004015305.1_ASM401530v1_genomic
#      |                       |  |  |
#      |                       |  |  |   /-s__Akkermansia muciniphila | 1 | GCF_003716915.1_ASM371691v1_genomic
#      |                       |  |   \-|
#      |                       |  |      \-s__Akkermansia muciniphila | 1 | GCA_014872005.1_ASM1487200v1_genomic
#      |                       |  |
#      |                        \-|   /-s__Akkermansia muciniphila | 1 | GCF_002885625.1_ASM288562v1_genomic
#      |                          |  |
#      |                          |  |         /-s__Akkermansia muciniphila | 1 | GCF_002885595.1_ASM288559v1_genomic
#      |                          |  |      /-|
#      |                          |  |     |   \-s__Akkermansia muciniphila | 1 | GCA_905205055.1_SRR413729-mag-bin.10_genomic
#      |                          |  |     |
#      |                          |  |   /-|      /-s__Akkermansia muciniphila | 1 | GCF_002885165.1_ASM288516v1_genomic
#      |                          |  |  |  |   /-|
#      |                          |  |  |  |  |   \-s__Akkermansia muciniphila | 1 | GCF_002885615.1_ASM288561v1_genomic
#      |                          |  |  |   \-|
#      |                           \-|  |     |   /-s__Akkermansia muciniphila | 1 | GCF_010223405.1_ASM1022340v1_genomic
#      |                             |  |      \-|
#      |                             |  |        |   /-s__Akkermansia muciniphila | 1 | GCF_010223575.1_ASM1022357v1_genomic
#      |                             |  |         \-|
#      |                             |  |            \-s__Akkermansia muciniphila | 1 | GCF_010223135.1_ASM1022313v1_genomic
#      |                             |  |
#      |                             |  |            /-s__Akkermansia muciniphila | 1 | GCF_010223075.1_ASM1022307v1_genomic
#      |                             |  |         /-|
#      |                             |  |      /-|   \-s__Akkermansia muciniphila | 1 | GCF_010223015.1_ASM1022301v1_genomic
#      |                             |  |     |  |
#      |                              \-|     |   \-s__Akkermansia muciniphila | 1 | GCF_002885215.1_ASM288521v1_genomic
#      |                                |   /-|
#      |                                |  |  |   /-s__Akkermansia muciniphila | 1 | GCA_014872105.1_ASM1487210v1_genomic
#      |                                |  |  |  |
#      |                                |  |   \-|   /-s__Akkermansia muciniphila | 1 | GCF_003716975.1_ASM371697v1_genomic
#      |                                |  |     |  |
#      |                                |  |      \-|   /-s__Akkermansia muciniphila | 1 | GCF_004015045.1_ASM401504v1_genomic
#      |                                |  |        |  |
#      |                                |  |         \-|   /-s__Akkermansia muciniphila | 1 | GCF_004015025.1_ASM401502v1_genomic
#      |                                |  |           |  |
#      |                                |  |            \-|      /-s__Akkermansia muciniphila | 1 | GCF_004015285.1_ASM401528v1_genomic
#      |                                |  |              |   /-|
#      |                                |  |               \-|   \-s__Akkermansia muciniphila | 1 | GCF_004015005.1_ASM401500v1_genomic
#      |                                |  |                 |
#      |                                 \-|                  \-s__Akkermansia muciniphila | 1 | GCF_004015065.1_ASM401506v1_genomic
#      |                                   |
#      |                                   |   /-s__Akkermansia muciniphila | 1 | GCF_004015265.1_ASM401526v1_genomic
#      |                                   |  |
#      |                                   |  |      /-s__Akkermansia muciniphila | 1 | GCF_010229055.1_ASM1022905v1_genomic
#      |                                   |  |     |
#      |                                   |  |     |      /-s__Akkermansia muciniphila | 1 | GCF_002885265.1_ASM288526v1_genomic
#      |                                   |  |   /-|   /-|
#      |                                   |  |  |  |  |   \-s__Akkermansia muciniphila | 1 | MGYG-HGUT-02454
#      |                                   |  |  |  |  |
#      |                                   |  |  |   \-|      /-s__Akkermansia muciniphila | 1 | GCF_017570505.1_ASM1757050v1_genomic
#      |                                   |  |  |     |   /-|
#      |                                   |  |  |     |  |   \-s__Akkermansia muciniphila | 1 | GCF_017570485.1_ASM1757048v1_genomic
#      |                                   |  |  |      \-|
#      |                                    \-|  |        |   /-s__Akkermansia muciniphila | 1 | GCF_017570425.1_ASM1757042v1_genomic
#      |                                      |  |         \-|
#      |                                      |  |            \-s__Akkermansia muciniphila | 1 | GCF_017570525.1_ASM1757052v1_genomic
#      |                                      |  |
#      |                                      |  |         /-s__Akkermansia muciniphila | 1 | GCF_010223255.1_ASM1022325v1_genomic
#      |                                      |  |      /-|
#      |                                      |  |     |   \-s__Akkermansia muciniphila | 1 | GCF_010223175.1_ASM1022317v1_genomic
#      |                                      |  |   /-|
#      |                                      |  |  |  |   /-s__Akkermansia muciniphila | 1 | GCF_004015105.1_ASM401510v1_genomic
#      |                                      |  |  |  |  |
#      |                                      |  |  |   \-|   /-s__Akkermansia muciniphila | 1 | GCF_010223195.1_ASM1022319v1_genomic
#      |                                      |  |  |     |  |
#      |                                      |  |  |      \-|      /-s__Akkermansia muciniphila | 1 | GCF_004015345.1_ASM401534v1_genomic
#      |                                       \-|  |        |   /-|
#      |                                         |  |        |  |   \-s__Akkermansia muciniphila | 1 | GCF_004015125.1_ASM401512v1_genomic
#      |                                         |  |         \-|
#      |                                         |  |           |   /-s__Akkermansia muciniphila | 1 | GCF_010223155.1_ASM1022315v1_genomic
#      |                                         |  |            \-|
#      |                                         |  |               \-s__Akkermansia muciniphila | 1 | GCF_004015325.1_ASM401532v1_genomic
#      |                                         |  |
#      |                                         |  |                  /-s__Akkermansia muciniphila | 1 | GCF_008422665.1_ASM842266v1_genomic
#      |                                         |  |                 |
#      |                                         |  |                 |--s__Akkermansia muciniphila | 1 | GCF_008422925.1_ASM842292v1_genomic
#      |                                         |  |               /-|
#      |                                         |  |              |  |--s__Akkermansia muciniphila | 1 | GCF_008423445.1_ASM842344v1_genomic
#      |                                         |  |              |  |
#      |                                         |  |            /-|   \-s__Akkermansia muciniphila | 1 | GCF_008422615.1_ASM842261v1_genomic
#      |                                         |  |           |  |
#      |                                         |  |           |  |   /-s__Akkermansia muciniphila | 1 | GCF_008423065.1_ASM842306v1_genomic
#      |                                         |  |           |   \-|
#      |                                         |  |           |      \-s__Akkermansia muciniphila | 1 | GCF_008422695.1_ASM842269v1_genomic
#      |                                         |  |         /-|
#      |                                         |  |        |  |      /-s__Akkermansia muciniphila | 1 | GCF_008422635.1_ASM842263v1_genomic
#      |                                          \-|        |  |     |
#      |                                            |        |  |   /-|--s__Akkermansia muciniphila | 1 | GCF_008423405.1_ASM842340v1_genomic
#      |                                            |        |  |  |  |
#      |                                            |        |  |  |   \-s__Akkermansia muciniphila | 1 | GCF_008422715.1_ASM842271v1_genomic
#      |                                            |        |   \-|
#      |                                            |        |     |      /-s__Akkermansia muciniphila | 1 | GCF_008422985.1_ASM842298v1_genomic
#      |                                            |        |     |   /-|
#      |                                            |      /-|     |  |  |   /-s__Akkermansia muciniphila | 1 | GCF_008422775.1_ASM842277v1_genomic
#      |                                            |     |  |      \-|   \-|
#      |                                            |     |  |        |      \-s__Akkermansia muciniphila | 1 | GCF_008422995.1_ASM842299v1_genomic
#      |                                            |     |  |        |
#      |                                            |     |  |         \-s__Akkermansia muciniphila | 1 | GCF_008423335.1_ASM842333v1_genomic
#      |                                            |     |  |
#      |                                            |     |  |      /-s__Akkermansia muciniphila | 1 | GCF_008422885.1_ASM842288v1_genomic
#      |                                            |   /-|  |   /-|
#      |                                            |  |  |  |  |  |   /-s__Akkermansia muciniphila | 1 | GCF_008423275.1_ASM842327v1_genomic
#      |                                            |  |  |   \-|   \-|
#      |                                            |  |  |     |      \-s__Akkermansia muciniphila | 1 | GCF_008423215.1_ASM842321v1_genomic
#      |                                            |  |  |     |
#      |                                            |  |  |      \-s__Akkermansia muciniphila | 1 | GCF_008423385.1_ASM842338v1_genomic
#      |                                            |  |  |
#      |                                            |  |  |   /-s__Akkermansia muciniphila | 1 | GCF_008423245.1_ASM842324v1_genomic
#      |                                            |  |   \-|
#      |                                            |  |     |   /-s__Akkermansia muciniphila | 1 | GCF_008423295.1_ASM842329v1_genomic
#      |                                            |  |      \-|
#      |                                            |  |         \-s__Akkermansia muciniphila | 1 | GCF_008423375.1_ASM842337v1_genomic
#      |                                             \-|
#      |                                               |         /-s__Akkermansia muciniphila | 1 | GCF_008423265.1_ASM842326v1_genomic
#      |                                               |      /-|
#      |                                               |   /-|   \-s__Akkermansia muciniphila | 1 | GCF_008423135.1_ASM842313v1_genomic
#      |                                               |  |  |
#      |                                               |  |   \-s__Akkermansia muciniphila | 1 | GCF_008422965.1_ASM842296v1_genomic
#      |                                               |  |
#      |                                               |  |         /-s__Akkermansia muciniphila | 1 | GCF_008423175.1_ASM842317v1_genomic
#      |                                               |  |      /-|
#      |                                               |  |     |   \-s__Akkermansia muciniphila | 1 | GCF_008422705.1_ASM842270v1_genomic
#      |                                               |  |   /-|
#      |                                               |  |  |  |   /-s__Akkermansia muciniphila | 1 | GCF_008423035.1_ASM842303v1_genomic
#      |                                                \-|  |  |  |
#      |                                                  |  |   \-|   /-s__Akkermansia muciniphila | 1 | GCF_008423325.1_ASM842332v1_genomic
#      |                                                  |  |     |  |
#      |                                                  |  |      \-|      /-s__Akkermansia muciniphila | 1 | GCF_008422815.1_ASM842281v1_genomic
#      |                                                  |  |        |   /-|
#      |                                                  |  |        |  |   \-s__Akkermansia muciniphila | 1 | GCF_008423095.1_ASM842309v1_genomic
#      |                                                  |  |         \-|
#      |                                                  |  |           |   /-s__Akkermansia muciniphila | 1 | GCF_008422765.1_ASM842276v1_genomic
#      |                                                  |  |            \-|
#      |                                                   \-|              |   /-s__Akkermansia muciniphila | 1 | GCF_008422685.1_ASM842268v1_genomic
#      |                                                     |               \-|
#      |                                                     |                  \-s__Akkermansia muciniphila | 1 | GCF_008422865.1_ASM842286v1_genomic
#      |                                                     |
#      |                                                     |         /-s__Akkermansia muciniphila | 1 | GCF_008422895.1_ASM842289v1_genomic
#      |                                                     |      /-|
#      |                                                     |     |   \-s__Akkermansia muciniphila | 1 | GCF_008422875.1_ASM842287v1_genomic
#      |                                                     |   /-|
#      |                                                     |  |  |   /-s__Akkermansia muciniphila | 1 | GCF_008423085.1_ASM842308v1_genomic
#      |                                                     |  |   \-|
#      |                                                     |  |     |   /-s__Akkermansia muciniphila | 1 | GCF_004168105.1_ASM416810v1_genomic
#      |                                                     |  |      \-|
#      |                                                      \-|         \-s__Akkermansia muciniphila | 1 | GCF_008423185.1_ASM842318v1_genomic
#      |                                                        |
#      |                                                        |      /-s__Akkermansia muciniphila | 1 | GCF_008422805.1_ASM842280v1_genomic
#      |                                                        |   /-|
#      |                                                        |  |   \-s__Akkermansia muciniphila | 1 | GCF_008423015.1_ASM842301v1_genomic
#      |                                                        |  |
#      |                                                         \-|      /-s__Akkermansia muciniphila | 1 | GCF_008423455.1_ASM842345v1_genomic
#      |                                                           |   /-|
#      |                                                           |  |   \-s__Akkermansia muciniphila | 1 | GCF_008423115.1_ASM842311v1_genomic
#      |                                                            \-|
#      |                                                              |   /-s__Akkermansia muciniphila | 1 | GCF_008422795.1_ASM842279v1_genomic
#      |                                                               \-|
#      |                                                                  \-s__Akkermansia muciniphila | 1 | GCF_008423365.1_ASM842336v1_genomic
#      |
#      |      /-s__Akkermansia glycaniphila | 1 | GCF_001683795.1_ASM168379v1_genomic
#      |   /-|
#      |  |   \-s__Akkermansia glycaniphila | 2 | GCF_900097105.1_WK001_genomic
#      |  |
#       \-|      /-s__Akkermansia sp900548895 | 1 | MGYG-HGUT-04532
#         |   /-|
#         |  |   \-s__Akkermansia sp900548895 | 2 | DGYMR06203__metabat2_low_PE.047.contigs
#         |  |
#          \-|      /-s__Akkermansia sp900766865 | 3 | MGYG-HGUT-03413
#            |   /-|
#            |  |   \-s__ | 2 | bin3c.184.contigs
#            |  |
#             \-|      /-s__ | 1 | bin3c.225.contigs
#               |   /-|
#               |  |   \-s__ | 1 | bin3c.174.contigs
#                \-|
#                  |      /-s__ | 3 | MGYG-HGUT-03447
#                  |   /-|
#                   \-|   \-s__ | 3 | E4_54_1-contigs
#                     |
#                      \-s__ | 1 | R28__metabat2_low_PE.030.contigs
