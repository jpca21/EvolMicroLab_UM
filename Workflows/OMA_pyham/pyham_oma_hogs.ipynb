# %% [markdown]
# # Studying evolution of HOGs with `pyham`

# %% [markdown]
# #### See full tutorial at https://zoo.cs.ucl.ac.uk/tutorials/tutorial_pyHam_get_started.html

# %% [markdown]
# ## Requirements
#
# PyHam needs hierarchical orthogroups in xml format and a species tree (newick or phyloxml). Those files can be created with [OMA standalone](https://omabrowser.org/standalone/).

# %% [markdown]
# ### Very quick OMA tutorial
#
# Go to the previous link to check the documentation.
#
# #### Potential problems and solutions
#
# - When installing OMA, it may fails because isn't able to create a link to some executables, but it stills create the `oma`/`OMA` links which work. Also, It probably isn't needed to run the `install.sh` script if you run oma from a conda environment which has `numpy`, `biopython` and `lxml` installed.
# - When editing the parameter file (`OMA -p`), the outgroup definition should include only the string before the first `.`. So if you have as outgroup `GCF_000172155.1_ASM17215v1_genomic.fa`, you should include in the parameter file:
#
# ```
# OutgroupSpecies := ['GCF_000172155']
# ```
#
# - The amount of information printed to `stdout` is really big (after running 15 minutes, it created an out file of about 15 GBs), so in the sbatch file use:
#
# ```
# #SBATCH --output=/dev/null
# ```
#
# OMA is used in https://omabrowser.org/oma/home/

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import re
from collections import defaultdict
import matplotlib.pyplot as plt
import pickle

# %%
import ete3
from ete3 import Tree

# %%
pd.set_option('max_colwidth', 300)
pd.set_option('display.max_columns', 50)
# pd.set_option?

# %%
root = Path("/run/media/mibu/LR-orico_mini/Recovery_ADATA/Umayor/Work/Akker/OMA/Output")

# %% [markdown]
# Internal nodes don't have proper names

# %%
import pyham

# %%
# pyham.Ham?

# %%
# the orthoxml tree fails
xml_tree = "EstimatedSpeciesTree.phyloxml"
nwk_path = root.joinpath("EstimatedSpeciesTree.nwk").as_posix()
phyloxml_path = root.joinpath("EstimatedSpeciesTree.phyloxml").as_posix()
orthoxml_path = root.joinpath("HierarchicalGroups.orthoxml").as_posix()

# %%
pyham_analysis = pyham.Ham(nwk_path, orthoxml_path, tree_format='newick')

# %%
# EstimatedSpeciesTree.phyloxml with tree_format='phyloxml' fails
pyham_analysis = pyham.Ham(phyloxml_path, orthoxml_path, use_internal_name=True, tree_format='phyloxml')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-58f72e47b897> in <module>
# ----> 1 pyham_analysis = pyham.Ham(phyloxml_path, orthoxml_path, use_internal_name=True, tree_format='phyloxml')
#
# ~/miniconda3/envs/py38/lib/python3.8/site-packages/pyham/ham.py in __init__(self, tree_file, hog_file, type_hog_file, filter_object, use_internal_name, orthoXML_as_string, tree_format, phyloxml_internal_name_tag, phyloxml_leaf_name_tag, use_data_from, query_database, species_resolve_mode)
#     225             raise TypeError("{} is an invalid type phyloxml tag name")
#     226         self.species_resolve_mode = species_resolve_mode
# --> 227         self.taxonomy = tax.Taxonomy(self.tree_file, tree_format=tree_format, use_internal_name=use_internal_name, phyloxml_leaf_name_tag=phyloxml_leaf_name_tag, phyloxml_internal_name_tag=phyloxml_internal_name_tag)
#     228         logger.info('Build taxonomy: completed.')
#     229
#
# ~/miniconda3/envs/py38/lib/python3.8/site-packages/pyham/taxonomy.py in __init__(self, tree_file, tree_format, use_internal_name, phyloxml_leaf_name_tag, phyloxml_internal_name_tag, quoted_node_names)
#      45
#      46         # create tree
# ---> 47         self.tree = self._build_tree(tree_file, tree_format, quoted_node_names)
#      48
#      49         # create internal node name if required
#
# ~/miniconda3/envs/py38/lib/python3.8/site-packages/pyham/taxonomy.py in _build_tree(self, tree_file, tree_format, quoted_node_names)
#     268                 # assign name to ancestral species
#     269                 elif self.use_internal_name:
# --> 270                     node.name = self._get_name_phyloxml(node, self.phyloxml_internal_name_tag)
#     271
#     272             return tree
#
# ~/miniconda3/envs/py38/lib/python3.8/site-packages/pyham/taxonomy.py in _get_name_phyloxml(self, node, phyloxml_species_name_tag)
#     226
#     227         elif phyloxml_species_name_tag == 'taxonomy_scientific_name':
# --> 228             if node.phyloxml_clade.taxonomy[0].scientific_name != '':
#     229                 return node.phyloxml_clade.taxonomy[0].scientific_name
#     230             else:
#
# IndexError: list index out of range

# %% [markdown]
# ## `pyham_analysis.taxonomy.tree` points to an `ete3` tree

# %%
# This is a ete3 tree object
print(pyham_analysis.taxonomy.tree), type(pyham_analysis.taxonomy.tree)
# Out:
#          /-GCF_001683795
#         |
#       /-|   /-MGYG-HGUT-04532
#      |  |  |
#      |  |  |         /-bin3c
#      |   \-|      /-|
#      |     |   /-|   \-MGYG-HGUT-03447
#      |     |  |  |
#      |      \-|   \-R28__metabat2_low_PE
#      |        |
#      |         \-MGYG-HGUT-03413
#    /-|
#   |  |         /-MGYG-HGUT-02378
#   |  |      /-|
#   |  |     |   \-MGYG-HGUT-00870
#   |  |     |
#   |  |   /-|      /-MGYG-HGUT-02453
#   |  |  |  |   /-|
#   |  |  |  |  |   \-MGYG-HGUT-02452
#   |  |  |   \-|
# --|  |  |     |      /-MGYG-HGUT-02454
#   |   \-|     |   /-|
#   |     |      \-|   \-MGYG-HGUT-01921
#   |     |        |
#   |     |         \-MGYG-HGUT-01881
#   |     |
#   |     |   /-MGYG-HGUT-02584
#   |      \-|
#   |         \-F157a_European_Toad__metabat2_high_PE
#   |
#    \-GCF_000172155
# (None, ete3.coretype.tree.TreeNode)

# %% [markdown]
# **If we use `use_internal_name=True` when creating the pyham object, we get the node support as node names, which won't allow to build a tree profile `pyham_analysis.create_tree_profile` because repeated keys. If we use `use_internal_name=False` (default), nodes will have long names (see below), so better to parse the tree beforehand**

# %%
for node in pyham_analysis.taxonomy.tree.traverse():
    print(node.name, node.dist, node.depth)
node.features
# Out:
# GCF_001683795/MGYG-HGUT-04532/bin3c/MGYG-HGUT-03447/R28__metabat2_low_PE/MGYG-HGUT-03413/MGYG-HGUT-02378/MGYG-HGUT-00870/MGYG-HGUT-02453/MGYG-HGUT-02452/MGYG-HGUT-02454/MGYG-HGUT-01921/MGYG-HGUT-01881/MGYG-HGUT-02584/F157a_European_Toad__metabat2_high_PE/GCF_000172155 0.0 0
# GCF_001683795/MGYG-HGUT-04532/bin3c/MGYG-HGUT-03447/R28__metabat2_low_PE/MGYG-HGUT-03413/MGYG-HGUT-02378/MGYG-HGUT-00870/MGYG-HGUT-02453/MGYG-HGUT-02452/MGYG-HGUT-02454/MGYG-HGUT-01921/MGYG-HGUT-01881/MGYG-HGUT-02584/F157a_European_Toad__metabat2_high_PE 10.809459 1
# GCF_000172155 29.766209 1
# GCF_001683795/MGYG-HGUT-04532/bin3c/MGYG-HGUT-03447/R28__metabat2_low_PE/MGYG-HGUT-03413 2.3454421 2
# MGYG-HGUT-02378/MGYG-HGUT-00870/MGYG-HGUT-02453/MGYG-HGUT-02452/MGYG-HGUT-02454/MGYG-HGUT-01921/MGYG-HGUT-01881/MGYG-HGUT-02584/F157a_European_Toad__metabat2_high_PE 3.7313062 2
# GCF_001683795 13.075742 3
# MGYG-HGUT-04532/bin3c/MGYG-HGUT-03447/R28__metabat2_low_PE/MGYG-HGUT-03413 9.6068781 3
# MGYG-HGUT-02378/MGYG-HGUT-00870/MGYG-HGUT-02453/MGYG-HGUT-02452/MGYG-HGUT-02454/MGYG-HGUT-01921/MGYG-HGUT-01881 9.6259789 3
# MGYG-HGUT-02584/F157a_European_Toad__metabat2_high_PE 1.7257236 3
# MGYG-HGUT-04532 11.204408 4
# bin3c/MGYG-HGUT-03447/R28__metabat2_low_PE/MGYG-HGUT-03413 0.5930457 4
# MGYG-HGUT-02378/MGYG-HGUT-00870 2.7277175 4
# MGYG-HGUT-02453/MGYG-HGUT-02452/MGYG-HGUT-02454/MGYG-HGUT-01921/MGYG-HGUT-01881 1.5880354 4
# MGYG-HGUT-02584 12.04074 4
# F157a_European_Toad__metabat2_high_PE 13.079737 4
# bin3c/MGYG-HGUT-03447/R28__metabat2_low_PE 0.65690213 5
# MGYG-HGUT-03413 9.8484643 5
# MGYG-HGUT-02378 0.73541209 5
# MGYG-HGUT-00870 0.79740792 5
# MGYG-HGUT-02453/MGYG-HGUT-02452 0.40270864 5
# MGYG-HGUT-02454/MGYG-HGUT-01921/MGYG-HGUT-01881 1.5751598 5
# bin3c/MGYG-HGUT-03447 0.46532771 6
# R28__metabat2_low_PE 10.322653 6
# MGYG-HGUT-02453 1.2244801 6
# MGYG-HGUT-02452 1.7225945 6
# MGYG-HGUT-02454/MGYG-HGUT-01921 0.086008184 6
# MGYG-HGUT-01881 0.75576745 6
# bin3c 8.5325229 7
# MGYG-HGUT-03447 8.8712461 7
# MGYG-HGUT-02454 0.6250568 7
# MGYG-HGUT-01921 0.62085232 7
# {'depth', 'dist', 'genome', 'name', 'support'}

# %% [markdown]
# ## Parsing the node names of the `newick` file

# %%
tree = Tree(nwk_path, format=1)
# print(tree)

# %%
for i, node in enumerate(tree.traverse()):
    if not node.is_leaf():
        node.name = 'N' + str(i)
        print(node.name)
tree_outf = root.joinpath('EstimatedSpeciesTree_edited.nwk')
tree.write(format=1, outfile=tree_outf.as_posix())
# Out:
# N0
# N1
# N3
# N4
# N6
# N7
# N8
# N10
# N11
# N12
# N15
# N19
# N20
# N21
# N25

# %% [markdown]
# ## Create the pyham object again from the new edited tree
#
# **This time the tree should have proper node names**

# %%
# the orthoxml tree fails
nwk_path = root.joinpath("EstimatedSpeciesTree_edited.nwk").as_posix()
orthoxml_path = root.joinpath("HierarchicalGroups.orthoxml").as_posix()

# %%
# EstimatedSpeciesTree.phyloxml with tree_format='phyloxml' fails
pyham_analysis = pyham.Ham(nwk_path, orthoxml_path, use_internal_name=True, tree_format='newick')

# %%
for node in pyham_analysis.taxonomy.tree.traverse():
    print(node.name, node.dist, node.depth)
node.features
# Out:
#  0.0 0
# N1 10.8095 1
# GCF_000172155 29.7662 1
# N3 2.34544 2
# N4 3.73131 2
# GCF_001683795 13.0757 3
# N6 9.60688 3
# N7 9.62598 3
# N8 1.72572 3
# MGYG-HGUT-04532 11.2044 4
# N10 0.593046 4
# N11 2.72772 4
# N12 1.58804 4
# MGYG-HGUT-02584 12.0407 4
# F157a_European_Toad__metabat2_high_PE 13.0797 4
# N15 0.656902 5
# MGYG-HGUT-03413 9.84846 5
# MGYG-HGUT-02378 0.735412 5
# MGYG-HGUT-00870 0.797408 5
# N19 0.402709 5
# N20 1.57516 5
# N21 0.465328 6
# R28__metabat2_low_PE 10.3227 6
# MGYG-HGUT-02453 1.22448 6
# MGYG-HGUT-02452 1.72259 6
# N25 0.0860082 6
# MGYG-HGUT-01881 0.755767 6
# bin3c 8.53252 7
# MGYG-HGUT-03447 8.87125 7
# MGYG-HGUT-02454 0.625057 7
# MGYG-HGUT-01921 0.620852 7
# {'depth', 'dist', 'genome', 'name', 'support'}

# %%
# pyham_analysis.get_list_ancestral_genomes()

# %%
hogs_dict = pyham_analysis.get_dict_top_level_hogs()
# pyham_analysis.get_list_top_level_hogs()
len(hogs_dict)
# Out:
# 3785

# %%
hogs_dict['10']
# Out:
# <HOG(10)>

# %%
pyham_analysis.get_list_top_level_hogs()[:10]
# Out:
# [<HOG(1)>,
#  <HOG(2)>,
#  <HOG(3)>,
#  <HOG(4)>,
#  <HOG(5)>,
#  <HOG(6)>,
#  <HOG(7)>,
#  <HOG(8)>,
#  <HOG(9)>,
#  <HOG(10)>]

# %%
pyham_analysis.hog_file_type, pyham_analysis.tree_file
# Out:
# ('orthoxml',
#  '/run/media/mibu/LR-orico_mini/Recovery_ADATA/Umayor/Work/Akker/OMA/Output/EstimatedSpeciesTree_edited.nwk')

# %%
node.genome.name, node.genome.get_number_genes(), node.genome.taxon,  node.name#, node.genome.genes
# Out:
# ('MGYG-HGUT-01921',
#  2346,
#  Tree node 'MGYG-HGUT-01921' (0x7f878d734e8),
#  'MGYG-HGUT-01921')

# %%
len(pyham_analysis.extant_gene_map), pyham_analysis.extant_gene_map['1703']
# Out:
# (41064, Gene(1703))

# %%
list_genome = pyham_analysis.get_list_extant_genomes()
for g in list_genome:
    print(g)
# Out:
# MGYG-HGUT-01881
# MGYG-HGUT-02454
# MGYG-HGUT-03413
# MGYG-HGUT-02453
# MGYG-HGUT-00870
# F157a_European_Toad__metabat2_high_PE
# MGYG-HGUT-01921
# MGYG-HGUT-02584
# MGYG-HGUT-04532
# MGYG-HGUT-02452
# bin3c
# MGYG-HGUT-03447
# GCF_001683795
# R28__metabat2_low_PE
# GCF_000172155
# MGYG-HGUT-02378

# %%
ag_ls = pyham_analysis.get_list_ancestral_genomes()
for ag in ag_ls:
    print(ag)
# Out:
# N21
# N6
# N11
# N4
# N1
# N15
# N3
# N7
#
# N25
# N20
# N12
# N8
# N19
# N10

# %%
gene3  = pyham_analysis.get_gene_by_id(3)
gene12 = pyham_analysis.get_gene_by_id(12)
gene3, gene12
# Out:
# (Gene(3), Gene(12))

# %%
gene3.get_top_level_hog(), gene12.get_top_level_hog()
# Out:
# (<HOG(3080)>, Gene(12))

# %%
gene = pyham_analysis.get_gene_by_id(12)
hog = pyham_analysis.get_hog_by_id(1703)

# %%
hog.get_all_descendant_genes()
# Out:
# [Gene(10279),
#  Gene(36295),
#  Gene(31508),
#  Gene(38292),
#  Gene(39539),
#  Gene(27977),
#  Gene(1528),
#  Gene(19314),
#  Gene(12470),
#  Gene(25579),
#  Gene(21231),
#  Gene(14295),
#  Gene(26660),
#  Gene(17529)]

# %% [markdown]
# **Get the relevant information about genes**

# %%
gene.get_dict_xref()
# Out:
# {'id': '12', 'protId': 'GPIGBLJI_00012 hypothetical protein'}

# %%
from IPython.display import IFrame

# %% [markdown]
# ## Built-in interactive visualizations

# %%
pyham_analysis.create_iHam(hog=hog,outfile="HOG{}.html".format(hog.hog_id));
IFrame("HOG{}.html".format(hog.hog_id), width=1200, height=800)
# Out:
#         <iframe
#             width="1200"
#             height="800"
#             src="HOG1703.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
treeprofile = pyham_analysis.create_tree_profile(outfile="tp.html")
IFrame("tp.html", width=800, height=600)
# Out:
#         <iframe
#             width="800"
#             height="600"
#             src="tp.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# ## Evolutionary history of genomes

# %% [markdown]
# ### Lateral comparison between two genomes

# %%
# MGYG-HGUT-01921
# MGYG-HGUT-02454
HGUT_01921 = pyham_analysis.get_extant_genome_by_name("MGYG-HGUT-01921")
HGUT_02454 = pyham_analysis.get_extant_genome_by_name("MGYG-HGUT-02454")

# Instanciate the gene mapping !
lateral_01921_02454 = pyham_analysis.compare_genomes_lateral(HGUT_01921, HGUT_02454) # The order doesn't matter!

# %%
# The identical genes (that stay single copies) 
print("IDENTICAL GENES")
for hogs, dict_genome_gene in lateral_01921_02454.get_retained().items():
    print(f"\nHOG at Euarchontoglires {hogs} is the ancestor of: ")
    for g, gene in dict_genome_gene.items():
        print(f"{gene} in {g}")
# Out:
# IDENTICAL GENES
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15835) in MGYG-HGUT-01921
# Gene(27234) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15836) in MGYG-HGUT-01921
# Gene(27233) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15837) in MGYG-HGUT-01921
# Gene(27232) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15838) in MGYG-HGUT-01921
# Gene(27231) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15839) in MGYG-HGUT-01921
# Gene(27230) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15840) in MGYG-HGUT-01921
# Gene(27229) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15841) in MGYG-HGUT-01921
# Gene(27228) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15842) in MGYG-HGUT-01921
# Gene(27227) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15843) in MGYG-HGUT-01921
# Gene(27226) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15844) in MGYG-HGUT-01921
# Gene(27225) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15845) in MGYG-HGUT-01921
# Gene(27224) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15846) in MGYG-HGUT-01921
# Gene(27223) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15847) in MGYG-HGUT-01921
# Gene(27222) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15848) in MGYG-HGUT-01921
# Gene(27221) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15849) in MGYG-HGUT-01921
# Gene(27220) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15850) in MGYG-HGUT-01921
# Gene(27219) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15851) in MGYG-HGUT-01921
# Gene(27218) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15852) in MGYG-HGUT-01921
# Gene(27217) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15853) in MGYG-HGUT-01921
# Gene(27216) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15854) in MGYG-HGUT-01921
# Gene(27215) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15855) in MGYG-HGUT-01921
# Gene(27214) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15856) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15857) in MGYG-HGUT-01921
# Gene(27211) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15858) in MGYG-HGUT-01921
# Gene(27210) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15859) in MGYG-HGUT-01921
# Gene(27209) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15860) in MGYG-HGUT-01921
# Gene(27208) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15861) in MGYG-HGUT-01921
# Gene(27207) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15862) in MGYG-HGUT-01921
# Gene(27206) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15863) in MGYG-HGUT-01921
# Gene(27205) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15864) in MGYG-HGUT-01921
# Gene(27204) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15866) in MGYG-HGUT-01921
# Gene(27203) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15867) in MGYG-HGUT-01921
# Gene(27202) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15868) in MGYG-HGUT-01921
# Gene(27201) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15869) in MGYG-HGUT-01921
# Gene(27200) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15870) in MGYG-HGUT-01921
# Gene(27199) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15871) in MGYG-HGUT-01921
# Gene(27198) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15872) in MGYG-HGUT-01921
# Gene(27197) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15873) in MGYG-HGUT-01921
# Gene(27196) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15874) in MGYG-HGUT-01921
# Gene(27195) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15875) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15876) in MGYG-HGUT-01921
# Gene(27193) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15877) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15878) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15879) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15880) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15881) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15882) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15883) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15884) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15886) in MGYG-HGUT-01921
# Gene(26848) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15887) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15888) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15889) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15890) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15891) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15892) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15893) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15894) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15895) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15896) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15897) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15898) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15899) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15900) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15904) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15905) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15906) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15910) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15911) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15912) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15913) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15914) in MGYG-HGUT-01921
# Gene(26213) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15918) in MGYG-HGUT-01921
# Gene(26214) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15920) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15922) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15924) in MGYG-HGUT-01921
# Gene(26867) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15927) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15928) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15929) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15933) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15937) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15938) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15939) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15944) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15945) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15946) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15947) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15948) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15949) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15950) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15951) in MGYG-HGUT-01921
# Gene(26858) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15953) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15956) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15957) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15959) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15960) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15961) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15962) in MGYG-HGUT-01921
# Gene(27192) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15963) in MGYG-HGUT-01921
# Gene(27191) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15964) in MGYG-HGUT-01921
# Gene(27190) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15965) in MGYG-HGUT-01921
# Gene(27189) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15966) in MGYG-HGUT-01921
# Gene(27188) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15967) in MGYG-HGUT-01921
# Gene(27187) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15968) in MGYG-HGUT-01921
# Gene(27186) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15969) in MGYG-HGUT-01921
# Gene(27185) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15970) in MGYG-HGUT-01921
# Gene(27184) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15971) in MGYG-HGUT-01921
# Gene(27183) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15972) in MGYG-HGUT-01921
# Gene(27182) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15973) in MGYG-HGUT-01921
# Gene(27181) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15974) in MGYG-HGUT-01921
# Gene(27180) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15975) in MGYG-HGUT-01921
# Gene(27179) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15976) in MGYG-HGUT-01921
# Gene(27178) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15977) in MGYG-HGUT-01921
# Gene(27177) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15978) in MGYG-HGUT-01921
# Gene(27176) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15979) in MGYG-HGUT-01921
# Gene(27175) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15980) in MGYG-HGUT-01921
# Gene(27174) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15981) in MGYG-HGUT-01921
# Gene(27167) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15982) in MGYG-HGUT-01921
# Gene(27166) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15983) in MGYG-HGUT-01921
# Gene(27165) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15984) in MGYG-HGUT-01921
# Gene(27164) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15985) in MGYG-HGUT-01921
# Gene(27163) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15986) in MGYG-HGUT-01921
# Gene(27162) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15987) in MGYG-HGUT-01921
# Gene(27161) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15988) in MGYG-HGUT-01921
# Gene(27160) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15990) in MGYG-HGUT-01921
# Gene(27158) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15991) in MGYG-HGUT-01921
# Gene(27157) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15992) in MGYG-HGUT-01921
# Gene(27156) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15993) in MGYG-HGUT-01921
# Gene(27155) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15994) in MGYG-HGUT-01921
# Gene(27154) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15995) in MGYG-HGUT-01921
# Gene(27153) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15996) in MGYG-HGUT-01921
# Gene(27152) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15997) in MGYG-HGUT-01921
# Gene(27151) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15998) in MGYG-HGUT-01921
# Gene(27150) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(15999) in MGYG-HGUT-01921
# Gene(27149) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16000) in MGYG-HGUT-01921
# Gene(27148) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16002) in MGYG-HGUT-01921
# Gene(27146) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16003) in MGYG-HGUT-01921
# Gene(27145) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16004) in MGYG-HGUT-01921
# Gene(27144) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16005) in MGYG-HGUT-01921
# Gene(27143) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16006) in MGYG-HGUT-01921
# Gene(27142) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16007) in MGYG-HGUT-01921
# Gene(27141) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16008) in MGYG-HGUT-01921
# Gene(27140) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16009) in MGYG-HGUT-01921
# Gene(27139) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16010) in MGYG-HGUT-01921
# Gene(27138) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16011) in MGYG-HGUT-01921
# Gene(27137) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16012) in MGYG-HGUT-01921
# Gene(27136) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16013) in MGYG-HGUT-01921
# Gene(27135) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16014) in MGYG-HGUT-01921
# Gene(27134) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16015) in MGYG-HGUT-01921
# Gene(27098) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16016) in MGYG-HGUT-01921
# Gene(27097) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16017) in MGYG-HGUT-01921
# Gene(27096) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16018) in MGYG-HGUT-01921
# Gene(27095) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16019) in MGYG-HGUT-01921
# Gene(27094) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16020) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16022) in MGYG-HGUT-01921
# Gene(27093) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16023) in MGYG-HGUT-01921
# Gene(27092) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16024) in MGYG-HGUT-01921
# Gene(27091) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16025) in MGYG-HGUT-01921
# Gene(27090) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16026) in MGYG-HGUT-01921
# Gene(27089) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16027) in MGYG-HGUT-01921
# Gene(27088) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16029) in MGYG-HGUT-01921
# Gene(27087) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16030) in MGYG-HGUT-01921
# Gene(27086) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16031) in MGYG-HGUT-01921
# Gene(27085) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16032) in MGYG-HGUT-01921
# Gene(27084) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16033) in MGYG-HGUT-01921
# Gene(27083) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16034) in MGYG-HGUT-01921
# Gene(27082) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16035) in MGYG-HGUT-01921
# Gene(27081) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16036) in MGYG-HGUT-01921
# Gene(27080) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16037) in MGYG-HGUT-01921
# Gene(27079) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16038) in MGYG-HGUT-01921
# Gene(27077) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16039) in MGYG-HGUT-01921
# Gene(27076) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16040) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16041) in MGYG-HGUT-01921
# Gene(27068) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16042) in MGYG-HGUT-01921
# Gene(27067) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16043) in MGYG-HGUT-01921
# Gene(27066) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16044) in MGYG-HGUT-01921
# Gene(27065) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16045) in MGYG-HGUT-01921
# Gene(27064) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16046) in MGYG-HGUT-01921
# Gene(27062) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16047) in MGYG-HGUT-01921
# Gene(27061) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16048) in MGYG-HGUT-01921
# Gene(27060) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16051) in MGYG-HGUT-01921
# Gene(27058) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16052) in MGYG-HGUT-01921
# Gene(27057) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16053) in MGYG-HGUT-01921
# Gene(27056) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16055) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16058) in MGYG-HGUT-01921
# Gene(27049) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16059) in MGYG-HGUT-01921
# Gene(27048) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16060) in MGYG-HGUT-01921
# Gene(27047) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16061) in MGYG-HGUT-01921
# Gene(27046) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16062) in MGYG-HGUT-01921
# Gene(27045) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16063) in MGYG-HGUT-01921
# Gene(27044) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16064) in MGYG-HGUT-01921
# Gene(27043) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16065) in MGYG-HGUT-01921
# Gene(27042) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16066) in MGYG-HGUT-01921
# Gene(27041) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16067) in MGYG-HGUT-01921
# Gene(27040) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16068) in MGYG-HGUT-01921
# Gene(27039) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16069) in MGYG-HGUT-01921
# Gene(27037) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16070) in MGYG-HGUT-01921
# Gene(27036) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16071) in MGYG-HGUT-01921
# Gene(27035) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16072) in MGYG-HGUT-01921
# Gene(27034) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16073) in MGYG-HGUT-01921
# Gene(27033) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16074) in MGYG-HGUT-01921
# Gene(27032) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16075) in MGYG-HGUT-01921
# Gene(27031) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16077) in MGYG-HGUT-01921
# Gene(27029) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16078) in MGYG-HGUT-01921
# Gene(27028) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16079) in MGYG-HGUT-01921
# Gene(27027) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16080) in MGYG-HGUT-01921
# Gene(27026) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16081) in MGYG-HGUT-01921
# Gene(27025) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16082) in MGYG-HGUT-01921
# Gene(27024) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16083) in MGYG-HGUT-01921
# Gene(27023) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16084) in MGYG-HGUT-01921
# Gene(27022) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16085) in MGYG-HGUT-01921
# Gene(27021) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16086) in MGYG-HGUT-01921
# Gene(27020) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16087) in MGYG-HGUT-01921
# Gene(27019) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16088) in MGYG-HGUT-01921
# Gene(27018) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16089) in MGYG-HGUT-01921
# Gene(27017) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16090) in MGYG-HGUT-01921
# Gene(27015) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16091) in MGYG-HGUT-01921
# Gene(27014) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16092) in MGYG-HGUT-01921
# Gene(27013) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16093) in MGYG-HGUT-01921
# Gene(27012) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16094) in MGYG-HGUT-01921
# Gene(27011) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16095) in MGYG-HGUT-01921
# Gene(27010) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16096) in MGYG-HGUT-01921
# Gene(27009) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16097) in MGYG-HGUT-01921
# Gene(27008) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16099) in MGYG-HGUT-01921
# Gene(27006) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16100) in MGYG-HGUT-01921
# Gene(27005) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16101) in MGYG-HGUT-01921
# Gene(27003) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16102) in MGYG-HGUT-01921
# Gene(27002) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16103) in MGYG-HGUT-01921
# Gene(27001) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16104) in MGYG-HGUT-01921
# Gene(27000) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16105) in MGYG-HGUT-01921
# Gene(26998) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16106) in MGYG-HGUT-01921
# Gene(26997) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16107) in MGYG-HGUT-01921
# Gene(26996) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16108) in MGYG-HGUT-01921
# Gene(26995) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16109) in MGYG-HGUT-01921
# Gene(26994) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16111) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16113) in MGYG-HGUT-01921
# Gene(25975) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16114) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16115) in MGYG-HGUT-01921
# Gene(26985) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16116) in MGYG-HGUT-01921
# Gene(26984) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16117) in MGYG-HGUT-01921
# Gene(26983) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16118) in MGYG-HGUT-01921
# Gene(26982) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16119) in MGYG-HGUT-01921
# Gene(26981) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16120) in MGYG-HGUT-01921
# Gene(26980) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16121) in MGYG-HGUT-01921
# Gene(26979) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16122) in MGYG-HGUT-01921
# Gene(26978) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16123) in MGYG-HGUT-01921
# Gene(26977) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16124) in MGYG-HGUT-01921
# Gene(26975) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16125) in MGYG-HGUT-01921
# Gene(26974) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16127) in MGYG-HGUT-01921
# Gene(26972) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16128) in MGYG-HGUT-01921
# Gene(26971) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16130) in MGYG-HGUT-01921
# Gene(26970) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16131) in MGYG-HGUT-01921
# Gene(26969) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16132) in MGYG-HGUT-01921
# Gene(26968) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16133) in MGYG-HGUT-01921
# Gene(26967) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16134) in MGYG-HGUT-01921
# Gene(26966) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16135) in MGYG-HGUT-01921
# Gene(26965) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16136) in MGYG-HGUT-01921
# Gene(26964) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16137) in MGYG-HGUT-01921
# Gene(26963) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16138) in MGYG-HGUT-01921
# Gene(26962) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16139) in MGYG-HGUT-01921
# Gene(26961) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16140) in MGYG-HGUT-01921
# Gene(26960) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16141) in MGYG-HGUT-01921
# Gene(26959) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16142) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16144) in MGYG-HGUT-01921
# Gene(26958) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16145) in MGYG-HGUT-01921
# Gene(26957) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16146) in MGYG-HGUT-01921
# Gene(26956) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16147) in MGYG-HGUT-01921
# Gene(26955) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16148) in MGYG-HGUT-01921
# Gene(26954) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16149) in MGYG-HGUT-01921
# Gene(26953) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16150) in MGYG-HGUT-01921
# Gene(26952) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16151) in MGYG-HGUT-01921
# Gene(26949) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16152) in MGYG-HGUT-01921
# Gene(26948) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16153) in MGYG-HGUT-01921
# Gene(26941) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16154) in MGYG-HGUT-01921
# Gene(26940) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16155) in MGYG-HGUT-01921
# Gene(26939) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16156) in MGYG-HGUT-01921
# Gene(26938) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16157) in MGYG-HGUT-01921
# Gene(26937) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16158) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16159) in MGYG-HGUT-01921
# Gene(26936) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16160) in MGYG-HGUT-01921
# Gene(26935) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16161) in MGYG-HGUT-01921
# Gene(26934) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16163) in MGYG-HGUT-01921
# Gene(26933) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16164) in MGYG-HGUT-01921
# Gene(26932) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16165) in MGYG-HGUT-01921
# Gene(26931) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16166) in MGYG-HGUT-01921
# Gene(26930) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16167) in MGYG-HGUT-01921
# Gene(26929) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16168) in MGYG-HGUT-01921
# Gene(26928) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16169) in MGYG-HGUT-01921
# Gene(26927) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16170) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16171) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16172) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16173) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16174) in MGYG-HGUT-01921
# Gene(26926) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16175) in MGYG-HGUT-01921
# Gene(26924) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16176) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16177) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16178) in MGYG-HGUT-01921
# Gene(26922) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16179) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16180) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16181) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16182) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16183) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16184) in MGYG-HGUT-01921
# Gene(26917) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16185) in MGYG-HGUT-01921
# Gene(26916) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16186) in MGYG-HGUT-01921
# Gene(26910) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16187) in MGYG-HGUT-01921
# Gene(26909) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16188) in MGYG-HGUT-01921
# Gene(26908) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16189) in MGYG-HGUT-01921
# Gene(26907) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16190) in MGYG-HGUT-01921
# Gene(26906) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16191) in MGYG-HGUT-01921
# Gene(26903) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16192) in MGYG-HGUT-01921
# Gene(26902) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16193) in MGYG-HGUT-01921
# Gene(26900) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16194) in MGYG-HGUT-01921
# Gene(26899) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16195) in MGYG-HGUT-01921
# Gene(26898) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16197) in MGYG-HGUT-01921
# Gene(26897) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16198) in MGYG-HGUT-01921
# Gene(26896) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16199) in MGYG-HGUT-01921
# Gene(26895) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16200) in MGYG-HGUT-01921
# Gene(26894) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16201) in MGYG-HGUT-01921
# Gene(27328) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16202) in MGYG-HGUT-01921
# Gene(27330) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16203) in MGYG-HGUT-01921
# Gene(27331) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16204) in MGYG-HGUT-01921
# Gene(27332) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16205) in MGYG-HGUT-01921
# Gene(27333) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16206) in MGYG-HGUT-01921
# Gene(27334) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16207) in MGYG-HGUT-01921
# Gene(27335) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16208) in MGYG-HGUT-01921
# Gene(27336) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16209) in MGYG-HGUT-01921
# Gene(27337) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16210) in MGYG-HGUT-01921
# Gene(27338) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16211) in MGYG-HGUT-01921
# Gene(27339) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16212) in MGYG-HGUT-01921
# Gene(27340) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16213) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16214) in MGYG-HGUT-01921
# Gene(27344) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16215) in MGYG-HGUT-01921
# Gene(27345) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16216) in MGYG-HGUT-01921
# Gene(27346) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16217) in MGYG-HGUT-01921
# Gene(27347) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16218) in MGYG-HGUT-01921
# Gene(27348) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16219) in MGYG-HGUT-01921
# Gene(27349) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16220) in MGYG-HGUT-01921
# Gene(27350) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16221) in MGYG-HGUT-01921
# Gene(27351) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16222) in MGYG-HGUT-01921
# Gene(27352) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16223) in MGYG-HGUT-01921
# Gene(27353) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16224) in MGYG-HGUT-01921
# Gene(27354) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16225) in MGYG-HGUT-01921
# Gene(27355) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16226) in MGYG-HGUT-01921
# Gene(27356) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16227) in MGYG-HGUT-01921
# Gene(27357) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16228) in MGYG-HGUT-01921
# Gene(27358) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16229) in MGYG-HGUT-01921
# Gene(27359) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16230) in MGYG-HGUT-01921
# Gene(27360) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16231) in MGYG-HGUT-01921
# Gene(27361) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16232) in MGYG-HGUT-01921
# Gene(27362) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16233) in MGYG-HGUT-01921
# Gene(27363) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16235) in MGYG-HGUT-01921
# Gene(27364) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16236) in MGYG-HGUT-01921
# Gene(27365) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16237) in MGYG-HGUT-01921
# Gene(27366) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16238) in MGYG-HGUT-01921
# Gene(27367) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16239) in MGYG-HGUT-01921
# Gene(27368) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16240) in MGYG-HGUT-01921
# Gene(27369) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16241) in MGYG-HGUT-01921
# Gene(27370) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16242) in MGYG-HGUT-01921
# Gene(27371) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16243) in MGYG-HGUT-01921
# Gene(27372) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16244) in MGYG-HGUT-01921
# Gene(27373) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16245) in MGYG-HGUT-01921
# Gene(27374) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16246) in MGYG-HGUT-01921
# Gene(27375) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16247) in MGYG-HGUT-01921
# Gene(27376) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16248) in MGYG-HGUT-01921
# Gene(27377) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16249) in MGYG-HGUT-01921
# Gene(27378) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16250) in MGYG-HGUT-01921
# Gene(27379) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16251) in MGYG-HGUT-01921
# Gene(27380) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16252) in MGYG-HGUT-01921
# Gene(27381) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16253) in MGYG-HGUT-01921
# Gene(27382) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16254) in MGYG-HGUT-01921
# Gene(27383) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16255) in MGYG-HGUT-01921
# Gene(27384) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16256) in MGYG-HGUT-01921
# Gene(27385) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16257) in MGYG-HGUT-01921
# Gene(27386) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16258) in MGYG-HGUT-01921
# Gene(27387) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16259) in MGYG-HGUT-01921
# Gene(27388) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16260) in MGYG-HGUT-01921
# Gene(27389) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16261) in MGYG-HGUT-01921
# Gene(27390) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16262) in MGYG-HGUT-01921
# Gene(27391) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16264) in MGYG-HGUT-01921
# Gene(27392) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16265) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16266) in MGYG-HGUT-01921
# Gene(27393) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16267) in MGYG-HGUT-01921
# Gene(27394) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16268) in MGYG-HGUT-01921
# Gene(27395) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16269) in MGYG-HGUT-01921
# Gene(27396) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16270) in MGYG-HGUT-01921
# Gene(27397) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16271) in MGYG-HGUT-01921
# Gene(27398) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16272) in MGYG-HGUT-01921
# Gene(27399) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16273) in MGYG-HGUT-01921
# Gene(27400) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16274) in MGYG-HGUT-01921
# Gene(27401) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16275) in MGYG-HGUT-01921
# Gene(27402) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16276) in MGYG-HGUT-01921
# Gene(27403) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16277) in MGYG-HGUT-01921
# Gene(27404) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16278) in MGYG-HGUT-01921
# Gene(27405) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16279) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16280) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16281) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16282) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16283) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16284) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16285) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16287) in MGYG-HGUT-01921
# Gene(27406) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16288) in MGYG-HGUT-01921
# Gene(27407) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16289) in MGYG-HGUT-01921
# Gene(27408) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16290) in MGYG-HGUT-01921
# Gene(27409) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16291) in MGYG-HGUT-01921
# Gene(27410) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16292) in MGYG-HGUT-01921
# Gene(27411) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16293) in MGYG-HGUT-01921
# Gene(27412) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16294) in MGYG-HGUT-01921
# Gene(27413) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16295) in MGYG-HGUT-01921
# Gene(27414) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16296) in MGYG-HGUT-01921
# Gene(27415) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16297) in MGYG-HGUT-01921
# Gene(27416) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16298) in MGYG-HGUT-01921
# Gene(27417) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16299) in MGYG-HGUT-01921
# Gene(27418) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16300) in MGYG-HGUT-01921
# Gene(27419) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16301) in MGYG-HGUT-01921
# Gene(27420) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16302) in MGYG-HGUT-01921
# Gene(27421) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16303) in MGYG-HGUT-01921
# Gene(27422) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16304) in MGYG-HGUT-01921
# Gene(27423) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16305) in MGYG-HGUT-01921
# Gene(27424) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16306) in MGYG-HGUT-01921
# Gene(27425) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16307) in MGYG-HGUT-01921
# Gene(27426) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16308) in MGYG-HGUT-01921
# Gene(27427) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16309) in MGYG-HGUT-01921
# Gene(27428) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16310) in MGYG-HGUT-01921
# Gene(27429) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16311) in MGYG-HGUT-01921
# Gene(27430) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16313) in MGYG-HGUT-01921
# Gene(27431) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16314) in MGYG-HGUT-01921
# Gene(27432) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16315) in MGYG-HGUT-01921
# Gene(27433) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16316) in MGYG-HGUT-01921
# Gene(27434) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16317) in MGYG-HGUT-01921
# Gene(27435) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16318) in MGYG-HGUT-01921
# Gene(27436) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16319) in MGYG-HGUT-01921
# Gene(27437) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16320) in MGYG-HGUT-01921
# Gene(27438) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(16321) in MGYG-HGUT-01921
# Gene(27439) in MGYG-HGUT-02454
#
# ...
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18115) in MGYG-HGUT-01921
# Gene(26597) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18116) in MGYG-HGUT-01921
# Gene(26598) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18117) in MGYG-HGUT-01921
# Gene(26599) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18118) in MGYG-HGUT-01921
# Gene(26600) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18119) in MGYG-HGUT-01921
# Gene(26601) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18120) in MGYG-HGUT-01921
# Gene(26602) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18121) in MGYG-HGUT-01921
# Gene(26603) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18123) in MGYG-HGUT-01921
# Gene(26605) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18124) in MGYG-HGUT-01921
# Gene(26606) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18125) in MGYG-HGUT-01921
# Gene(26607) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18126) in MGYG-HGUT-01921
# Gene(26608) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18127) in MGYG-HGUT-01921
# Gene(26609) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18128) in MGYG-HGUT-01921
# Gene(26610) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18130) in MGYG-HGUT-01921
# Gene(26612) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18131) in MGYG-HGUT-01921
# Gene(26613) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18132) in MGYG-HGUT-01921
# Gene(26614) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18133) in MGYG-HGUT-01921
# Gene(26615) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18134) in MGYG-HGUT-01921
# Gene(26616) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18135) in MGYG-HGUT-01921
# Gene(26617) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18136) in MGYG-HGUT-01921
# Gene(26618) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18137) in MGYG-HGUT-01921
# Gene(25835) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18138) in MGYG-HGUT-01921
# Gene(26620) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18139) in MGYG-HGUT-01921
# Gene(26621) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18140) in MGYG-HGUT-01921
# Gene(26622) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18141) in MGYG-HGUT-01921
# Gene(26623) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18142) in MGYG-HGUT-01921
# Gene(26624) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18143) in MGYG-HGUT-01921
# Gene(27327) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18144) in MGYG-HGUT-01921
# Gene(27326) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18145) in MGYG-HGUT-01921
# Gene(27325) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18146) in MGYG-HGUT-01921
# Gene(27324) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18147) in MGYG-HGUT-01921
# Gene(27323) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18148) in MGYG-HGUT-01921
# Gene(27322) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18149) in MGYG-HGUT-01921
# Gene(27321) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18150) in MGYG-HGUT-01921
# Gene(27320) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18151) in MGYG-HGUT-01921
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18152) in MGYG-HGUT-01921
# Gene(27318) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18153) in MGYG-HGUT-01921
# Gene(27317) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18157) in MGYG-HGUT-01921
# Gene(27315) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18158) in MGYG-HGUT-01921
# Gene(27314) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18159) in MGYG-HGUT-01921
# Gene(27313) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18160) in MGYG-HGUT-01921
# Gene(27312) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18161) in MGYG-HGUT-01921
# Gene(27311) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18162) in MGYG-HGUT-01921
# Gene(27310) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18163) in MGYG-HGUT-01921
# Gene(27309) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18164) in MGYG-HGUT-01921
# Gene(27308) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18165) in MGYG-HGUT-01921
# Gene(27307) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18166) in MGYG-HGUT-01921
# Gene(27306) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18167) in MGYG-HGUT-01921
# Gene(27305) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18168) in MGYG-HGUT-01921
# Gene(27304) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18169) in MGYG-HGUT-01921
# Gene(27303) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18170) in MGYG-HGUT-01921
# Gene(27302) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18171) in MGYG-HGUT-01921
# Gene(27301) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18173) in MGYG-HGUT-01921
# Gene(27300) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18174) in MGYG-HGUT-01921
# Gene(27299) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18175) in MGYG-HGUT-01921
# Gene(27298) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18176) in MGYG-HGUT-01921
# Gene(27297) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18177) in MGYG-HGUT-01921
# Gene(27296) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18178) in MGYG-HGUT-01921
# Gene(27295) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(18179) in MGYG-HGUT-01921
# Gene(27294) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(25644) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(25681) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(25725) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(25729) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(25768) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(25824) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(25834) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(25856) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(25867) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(25937) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(25943) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(25966) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(25971) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(25973) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(25977) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(25980) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(25993) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(25994) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(25995) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(26009) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(26103) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(26121) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(26150) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(26152) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(26155) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(26212) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(26412) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(26417) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(26418) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(26466) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(26468) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(26471) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(26487) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(26520) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(26521) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(26565) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(26574) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(26604) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(26611) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(26747) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(26828) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(26841) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(26843) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(26847) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(26849) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(26850) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(26855) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(26860) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(26870) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(26878) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(26891) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(26892) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(26893) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(26901) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(26911) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(26912) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(26920) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(26921) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(26923) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(26942) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(26943) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(26945) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(26946) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(26950) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(26951) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(26976) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(26990) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(26991) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(26993) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(27030) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(27059) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(27063) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(27101) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(27102) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(27106) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(27111) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(27113) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(27121) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(27122) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(27123) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(27124) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(27125) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(27147) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(27235) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(27236) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(27259) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(27278) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(27293) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(27316) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(27319) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(27456) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(27621) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(27641) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(27642) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(27643) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(27644) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(27646) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(27653) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(27690) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(27691) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(27700) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(27703) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(27716) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(27717) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(27759) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(27768) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(27772) in MGYG-HGUT-02454
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(27813) in MGYG-HGUT-02454

# %%
# The identical genes (that stay single copies) 
print("GAINED GENES")
for genome, gains in lateral_01921_02454.get_gained().items():
    print(f"\nHOG at Euarchontoglires {hogs} is the ancestor of: ")
    for g in gains:
        print(f"{gene} in {g}")
# Out:
# GAINED GENES
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(27813) in Gene(15865)
# Gene(27813) in Gene(15901)
# Gene(27813) in Gene(15902)
# Gene(27813) in Gene(15903)
# Gene(27813) in Gene(15907)
# Gene(27813) in Gene(15908)
# Gene(27813) in Gene(15909)
# Gene(27813) in Gene(15915)
# Gene(27813) in Gene(15916)
# Gene(27813) in Gene(15917)
# Gene(27813) in Gene(15919)
# Gene(27813) in Gene(15921)
# Gene(27813) in Gene(15923)
# Gene(27813) in Gene(15925)
# Gene(27813) in Gene(15926)
# Gene(27813) in Gene(15930)
# Gene(27813) in Gene(15931)
# Gene(27813) in Gene(15932)
# Gene(27813) in Gene(15934)
# Gene(27813) in Gene(15935)
# Gene(27813) in Gene(15936)
# Gene(27813) in Gene(15940)
# Gene(27813) in Gene(15941)
# Gene(27813) in Gene(15942)
# Gene(27813) in Gene(15943)
# Gene(27813) in Gene(15952)
# Gene(27813) in Gene(15954)
# Gene(27813) in Gene(15955)
# Gene(27813) in Gene(15989)
# Gene(27813) in Gene(16001)
# Gene(27813) in Gene(16021)
# Gene(27813) in Gene(16028)
# Gene(27813) in Gene(16049)
# Gene(27813) in Gene(16050)
# Gene(27813) in Gene(16054)
# Gene(27813) in Gene(16056)
# Gene(27813) in Gene(16057)
# Gene(27813) in Gene(16076)
# Gene(27813) in Gene(16098)
# Gene(27813) in Gene(16110)
# Gene(27813) in Gene(16112)
# Gene(27813) in Gene(16126)
# Gene(27813) in Gene(16129)
# Gene(27813) in Gene(16143)
# Gene(27813) in Gene(16162)
# Gene(27813) in Gene(16196)
# Gene(27813) in Gene(16234)
# Gene(27813) in Gene(16263)
# Gene(27813) in Gene(16286)
# Gene(27813) in Gene(16312)
# Gene(27813) in Gene(16324)
# Gene(27813) in Gene(16335)
# Gene(27813) in Gene(16343)
# Gene(27813) in Gene(16396)
# Gene(27813) in Gene(16432)
# Gene(27813) in Gene(16433)
# Gene(27813) in Gene(16474)
# Gene(27813) in Gene(16494)
# Gene(27813) in Gene(16520)
# Gene(27813) in Gene(16521)
# Gene(27813) in Gene(16549)
# Gene(27813) in Gene(16577)
# Gene(27813) in Gene(16579)
# Gene(27813) in Gene(16580)
# Gene(27813) in Gene(16581)
# Gene(27813) in Gene(16583)
# Gene(27813) in Gene(16585)
# Gene(27813) in Gene(16587)
# Gene(27813) in Gene(16588)
# Gene(27813) in Gene(16595)
# Gene(27813) in Gene(16709)
# Gene(27813) in Gene(16710)
# Gene(27813) in Gene(16740)
# Gene(27813) in Gene(16741)
# Gene(27813) in Gene(16759)
# Gene(27813) in Gene(16780)
# Gene(27813) in Gene(16821)
# Gene(27813) in Gene(16826)
# Gene(27813) in Gene(16831)
# Gene(27813) in Gene(16850)
# Gene(27813) in Gene(16877)
# Gene(27813) in Gene(16879)
# Gene(27813) in Gene(16921)
# Gene(27813) in Gene(16934)
# Gene(27813) in Gene(16935)
# Gene(27813) in Gene(16962)
# Gene(27813) in Gene(16963)
# Gene(27813) in Gene(16979)
# Gene(27813) in Gene(16980)
# Gene(27813) in Gene(16982)
# Gene(27813) in Gene(16983)
# Gene(27813) in Gene(16984)
# Gene(27813) in Gene(17012)
# Gene(27813) in Gene(17028)
# Gene(27813) in Gene(17033)
# Gene(27813) in Gene(17036)
# Gene(27813) in Gene(17061)
# Gene(27813) in Gene(17155)
# Gene(27813) in Gene(17218)
# Gene(27813) in Gene(17220)
# Gene(27813) in Gene(17254)
# Gene(27813) in Gene(17265)
# Gene(27813) in Gene(17279)
# Gene(27813) in Gene(17305)
# Gene(27813) in Gene(17307)
# Gene(27813) in Gene(17391)
# Gene(27813) in Gene(17394)
# Gene(27813) in Gene(17396)
# Gene(27813) in Gene(17398)
# Gene(27813) in Gene(17402)
# Gene(27813) in Gene(17410)
# Gene(27813) in Gene(17428)
# Gene(27813) in Gene(17431)
# Gene(27813) in Gene(17433)
# Gene(27813) in Gene(17437)
# Gene(27813) in Gene(17438)
# Gene(27813) in Gene(17439)
# Gene(27813) in Gene(17440)
# Gene(27813) in Gene(17444)
# Gene(27813) in Gene(17447)
# Gene(27813) in Gene(17474)
# Gene(27813) in Gene(17475)
# Gene(27813) in Gene(17476)
# Gene(27813) in Gene(17520)
# Gene(27813) in Gene(17567)
# Gene(27813) in Gene(17568)
# Gene(27813) in Gene(17570)
# Gene(27813) in Gene(17571)
# Gene(27813) in Gene(17575)
# Gene(27813) in Gene(17681)
# Gene(27813) in Gene(17690)
# Gene(27813) in Gene(17712)
# Gene(27813) in Gene(17716)
# Gene(27813) in Gene(17717)
# Gene(27813) in Gene(17770)
# Gene(27813) in Gene(17785)
# Gene(27813) in Gene(17786)
# Gene(27813) in Gene(17848)
# Gene(27813) in Gene(17849)
# Gene(27813) in Gene(17854)
# Gene(27813) in Gene(17865)
# Gene(27813) in Gene(17882)
# Gene(27813) in Gene(17889)
# Gene(27813) in Gene(17890)
# Gene(27813) in Gene(17893)
# Gene(27813) in Gene(17896)
# Gene(27813) in Gene(17901)
# Gene(27813) in Gene(17902)
# Gene(27813) in Gene(17904)
# Gene(27813) in Gene(17935)
# Gene(27813) in Gene(17938)
# Gene(27813) in Gene(17939)
# Gene(27813) in Gene(17940)
# Gene(27813) in Gene(17942)
# Gene(27813) in Gene(17947)
# Gene(27813) in Gene(17949)
# Gene(27813) in Gene(17950)
# Gene(27813) in Gene(17953)
# Gene(27813) in Gene(17955)
# Gene(27813) in Gene(17960)
# Gene(27813) in Gene(17974)
# Gene(27813) in Gene(17984)
# Gene(27813) in Gene(17994)
# Gene(27813) in Gene(18018)
# Gene(27813) in Gene(18081)
# Gene(27813) in Gene(18100)
# Gene(27813) in Gene(18107)
# Gene(27813) in Gene(18111)
# Gene(27813) in Gene(18122)
# Gene(27813) in Gene(18129)
# Gene(27813) in Gene(18154)
# Gene(27813) in Gene(18155)
# Gene(27813) in Gene(18156)
# Gene(27813) in Gene(18172)
# Gene(27813) in Gene(18180)
#
# HOG at Euarchontoglires <HOG()> is the ancestor of:
# Gene(27813) in Gene(25626)
# Gene(27813) in Gene(25627)
# Gene(27813) in Gene(25647)
# Gene(27813) in Gene(25656)
# Gene(27813) in Gene(25752)
# Gene(27813) in Gene(25790)
# Gene(27813) in Gene(25808)
# Gene(27813) in Gene(25811)
# Gene(27813) in Gene(25814)
# Gene(27813) in Gene(25816)
# Gene(27813) in Gene(25818)
# Gene(27813) in Gene(25843)
# Gene(27813) in Gene(25844)
# Gene(27813) in Gene(25845)
# Gene(27813) in Gene(25846)
# Gene(27813) in Gene(25847)
# Gene(27813) in Gene(25848)
# Gene(27813) in Gene(25849)
# Gene(27813) in Gene(25850)
# Gene(27813) in Gene(25851)
# Gene(27813) in Gene(25852)
# Gene(27813) in Gene(25853)
# Gene(27813) in Gene(25854)
# Gene(27813) in Gene(25855)
# Gene(27813) in Gene(25857)
# Gene(27813) in Gene(25935)
# Gene(27813) in Gene(25936)
# Gene(27813) in Gene(25938)
# Gene(27813) in Gene(25939)
# Gene(27813) in Gene(25972)
# Gene(27813) in Gene(25974)
# Gene(27813) in Gene(25976)
# Gene(27813) in Gene(25978)
# Gene(27813) in Gene(25979)
# Gene(27813) in Gene(25983)
# Gene(27813) in Gene(25984)
# Gene(27813) in Gene(25985)
# Gene(27813) in Gene(25989)
# Gene(27813) in Gene(25991)
# Gene(27813) in Gene(25992)
# Gene(27813) in Gene(26022)
# Gene(27813) in Gene(26058)
# Gene(27813) in Gene(26112)
# Gene(27813) in Gene(26122)
# Gene(27813) in Gene(26153)
# Gene(27813) in Gene(26154)
# Gene(27813) in Gene(26186)
# Gene(27813) in Gene(26215)
# Gene(27813) in Gene(26227)
# Gene(27813) in Gene(26239)
# Gene(27813) in Gene(26240)
# Gene(27813) in Gene(26305)
# Gene(27813) in Gene(26306)
# Gene(27813) in Gene(26339)
# Gene(27813) in Gene(26340)
# Gene(27813) in Gene(26348)
# Gene(27813) in Gene(26361)
# Gene(27813) in Gene(26362)
# Gene(27813) in Gene(26369)
# Gene(27813) in Gene(26372)
# Gene(27813) in Gene(26449)
# Gene(27813) in Gene(26450)
# Gene(27813) in Gene(26469)
# Gene(27813) in Gene(26472)
# Gene(27813) in Gene(26479)
# Gene(27813) in Gene(26504)
# Gene(27813) in Gene(26505)
# Gene(27813) in Gene(26514)
# Gene(27813) in Gene(26515)
# Gene(27813) in Gene(26531)
# Gene(27813) in Gene(26564)
# Gene(27813) in Gene(26589)
# Gene(27813) in Gene(26590)
# Gene(27813) in Gene(26619)
# Gene(27813) in Gene(26625)
# Gene(27813) in Gene(26669)
# Gene(27813) in Gene(26670)
# Gene(27813) in Gene(26687)
# Gene(27813) in Gene(26706)
# Gene(27813) in Gene(26743)
# Gene(27813) in Gene(26744)
# Gene(27813) in Gene(26749)
# Gene(27813) in Gene(26750)
# Gene(27813) in Gene(26768)
# Gene(27813) in Gene(26771)
# Gene(27813) in Gene(26790)
# Gene(27813) in Gene(26791)
# Gene(27813) in Gene(26831)
# Gene(27813) in Gene(26844)
# Gene(27813) in Gene(26845)
# Gene(27813) in Gene(26846)
# Gene(27813) in Gene(26851)
# Gene(27813) in Gene(26852)
# Gene(27813) in Gene(26853)
# Gene(27813) in Gene(26854)
# Gene(27813) in Gene(26856)
# Gene(27813) in Gene(26857)
# Gene(27813) in Gene(26859)
# Gene(27813) in Gene(26861)
# Gene(27813) in Gene(26862)
# Gene(27813) in Gene(26863)
# Gene(27813) in Gene(26864)
# Gene(27813) in Gene(26865)
# Gene(27813) in Gene(26866)
# Gene(27813) in Gene(26868)
# Gene(27813) in Gene(26869)
# Gene(27813) in Gene(26871)
# Gene(27813) in Gene(26872)
# Gene(27813) in Gene(26873)
# Gene(27813) in Gene(26874)
# Gene(27813) in Gene(26875)
# Gene(27813) in Gene(26876)
# Gene(27813) in Gene(26877)
# Gene(27813) in Gene(26879)
# Gene(27813) in Gene(26905)
# Gene(27813) in Gene(26913)
# Gene(27813) in Gene(26914)
# Gene(27813) in Gene(26915)
# Gene(27813) in Gene(26918)
# Gene(27813) in Gene(26919)
# Gene(27813) in Gene(26925)
# Gene(27813) in Gene(26944)
# Gene(27813) in Gene(26947)
# Gene(27813) in Gene(26973)
# Gene(27813) in Gene(26987)
# Gene(27813) in Gene(26988)
# Gene(27813) in Gene(26989)
# Gene(27813) in Gene(26992)
# Gene(27813) in Gene(26999)
# Gene(27813) in Gene(27004)
# Gene(27813) in Gene(27007)
# Gene(27813) in Gene(27016)
# Gene(27813) in Gene(27038)
# Gene(27813) in Gene(27052)
# Gene(27813) in Gene(27053)
# Gene(27813) in Gene(27054)
# Gene(27813) in Gene(27055)
# Gene(27813) in Gene(27069)
# Gene(27813) in Gene(27070)
# Gene(27813) in Gene(27071)
# Gene(27813) in Gene(27072)
# Gene(27813) in Gene(27073)
# Gene(27813) in Gene(27074)
# Gene(27813) in Gene(27075)
# Gene(27813) in Gene(27078)
# Gene(27813) in Gene(27100)
# Gene(27813) in Gene(27103)
# Gene(27813) in Gene(27104)
# Gene(27813) in Gene(27105)
# Gene(27813) in Gene(27107)
# Gene(27813) in Gene(27108)
# Gene(27813) in Gene(27110)
# Gene(27813) in Gene(27112)
# Gene(27813) in Gene(27114)
# Gene(27813) in Gene(27115)
# Gene(27813) in Gene(27116)
# Gene(27813) in Gene(27117)
# Gene(27813) in Gene(27118)
# Gene(27813) in Gene(27119)
# Gene(27813) in Gene(27120)
# Gene(27813) in Gene(27126)
# Gene(27813) in Gene(27127)
# Gene(27813) in Gene(27128)
# Gene(27813) in Gene(27129)
# Gene(27813) in Gene(27130)
# Gene(27813) in Gene(27131)
# Gene(27813) in Gene(27132)
# Gene(27813) in Gene(27133)
# Gene(27813) in Gene(27159)
# Gene(27813) in Gene(27168)
# Gene(27813) in Gene(27170)
# Gene(27813) in Gene(27171)
# Gene(27813) in Gene(27172)
# Gene(27813) in Gene(27173)
# Gene(27813) in Gene(27194)
# Gene(27813) in Gene(27212)
# Gene(27813) in Gene(27213)
# Gene(27813) in Gene(27247)
# Gene(27813) in Gene(27248)
# Gene(27813) in Gene(27249)
# Gene(27813) in Gene(27250)
# Gene(27813) in Gene(27251)
# Gene(27813) in Gene(27329)
# Gene(27813) in Gene(27341)
# Gene(27813) in Gene(27342)
# Gene(27813) in Gene(27343)
# Gene(27813) in Gene(27443)
# Gene(27813) in Gene(27444)
# Gene(27813) in Gene(27470)
# Gene(27813) in Gene(27527)
# Gene(27813) in Gene(27528)
# Gene(27813) in Gene(27529)
# Gene(27813) in Gene(27576)
# Gene(27813) in Gene(27577)
# Gene(27813) in Gene(27592)
# Gene(27813) in Gene(27615)
# Gene(27813) in Gene(27629)
# Gene(27813) in Gene(27645)
# Gene(27813) in Gene(27647)
# Gene(27813) in Gene(27648)
# Gene(27813) in Gene(27651)
# Gene(27813) in Gene(27652)
# Gene(27813) in Gene(27657)
# Gene(27813) in Gene(27685)
# Gene(27813) in Gene(27704)
# Gene(27813) in Gene(27705)
# Gene(27813) in Gene(27706)
# Gene(27813) in Gene(27707)
# Gene(27813) in Gene(27708)
# Gene(27813) in Gene(27709)
# Gene(27813) in Gene(27710)
# Gene(27813) in Gene(27711)
# Gene(27813) in Gene(27712)
# Gene(27813) in Gene(27713)
# Gene(27813) in Gene(27718)
# Gene(27813) in Gene(27719)
# Gene(27813) in Gene(27720)
# Gene(27813) in Gene(27746)
# Gene(27813) in Gene(27760)
# Gene(27813) in Gene(27761)
# Gene(27813) in Gene(27762)
# Gene(27813) in Gene(27763)
# Gene(27813) in Gene(27765)
# Gene(27813) in Gene(27806)
# Gene(27813) in Gene(27812)
# Gene(27813) in Gene(27818)
# Gene(27813) in Gene(27837)
# Gene(27813) in Gene(27844)
# Gene(27813) in Gene(27857)
# Gene(27813) in Gene(27862)
# Gene(27813) in Gene(27886)
